# %% [markdown]
# <a href="https://colab.research.google.com/github/cjcastagno/DS1002/blob/main/2_28_Assignment_Conall_Castagno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install english_words
from english_words import get_english_words_set
words = get_english_words_set(['web2'], lower=True)

# type(words)
wordlist = list(words)
len(wordlist)

#There are 234450 words in the list

alpha_list = sorted(wordlist)
print(alpha_list[0:10])

# printed out first 10 letters in alpha_list
words_with_a = 0
for words in alpha_list:
  if words[0] == 'a':
   words_with_a += 1
print(words_with_a)

# 16,982 words start with 'a'

letter = 'q'
q_count = len([ele for ele in alpha_list if letter in ele])
print(str(q_count))

# 3,624 words contain a q

letter = 'e'
e_count = len([ele for ele in alpha_list if letter in ele])
print(str(e_count))


# 157,484 words contain the letter 'e', 234450/157484 = 67.17% of words contain 'e', which means 38.83% of letters do not contain 'e'.
# Out:
# ...
# ['a', 'aa', 'aal', 'aalii', 'aam', 'aani', 'aardvark', 'aardwolf', 'aaron', 'aaronic']
# 16982
# 3624
# 157484

# %%
# !pip install english_words
from english_words import get_english_words_set
words = get_english_words_set(['web2'], lower=True)
import numpy as np
wordlist = list(words)
alpha_list = sorted(wordlist)
wordlist_array = np.array(wordlist)
alpha_list_array = np.array(alpha_list)
alphabet = [chr(i) for i in range(ord('a'),ord('z')+1)]



import matplotlib.pyplot as plt

letter_counts = {}

for word in alpha_list:
    first_letter = word[0].lower()
    if first_letter in letter_counts:
        letter_counts[first_letter] += 1
    else:
        letter_counts[first_letter] = 1

letters = list(letter_counts.keys())
counts = list(letter_counts.values())

plt.figure(figsize=(10, 6))
plt.bar(letters, counts,)

plt.xlabel('Letters')
plt.ylabel('Number of Words')
plt.title('Number of Words Starting with Each Letter')

plt.show()

# %%
# !pip install english_words
from english_words import get_english_words_set
words = get_english_words_set(['web2'], lower=True)

def find_k_longest_words(lst, k):
    sorted_lst = sorted(lst, key=len, reverse=True)
    return sorted_lst[:k]

wordlist = list(words)
k = 6
print(find_k_longest_words(wordlist, k))

# 6 longest words: 'antidisestablishmentarianism', 'formaldehydesulphoxylate', 'tetraiodophenolphthalein', 'pathologicopsychological', 'scientificophilosophical', 'thyroparathyroidectomize'
# Out:
# ...
# ['antidisestablishmentarianism', 'formaldehydesulphoxylate', 'tetraiodophenolphthalein', 'pathologicopsychological', 'scientificophilosophical', 'thyroparathyroidectomize']

# %%
# !pip install english_words
from english_words import get_english_words_set
words = get_english_words_set(['web2'], lower=True)
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

word_lengths = [len(word) for word in words]
plt.hist(word_lengths, bins=range(min(word_lengths), max(word_lengths) + 2), align='left', alpha=0.7, rwidth=0.8)
plt.xlabel('Word Length')
plt.ylabel('Number of Words')
plt.title('Word Length Histogram')
plt.show()

# Most common word length is 9 words

# %%
# !pip install english_words
from english_words import get_english_words_set
words = get_english_words_set(['web2'], lower=True)
count = 0
letter1 = 'a'
letter2 = 'v'
for word in words:
  if letter1 in word and letter2 in word:
    count += 1
count

# 11347 words contain both 'a' and 'v' - this was executed in roughly 7 seconds - I cannot see how many times the code looped through the list, but if I had to guess, it would be the same as the number of words since it's a for loop
# Out:
# ...
# 11347

# %%
# !pip install english_words
from english_words import get_english_words_set
words = get_english_words_set(['web2'], lower=True)
count = 0
letter1 = 'w'
letter2 = 'l'
for word in words:
  if letter1 in word and letter2 in word:
    count += 1
count
# 4822 words contain both 'l' and 'w' - this was executed in roughly 7 seconds
# Out:
# ...
# 4822
