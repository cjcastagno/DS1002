# %% [markdown]
# <a href="https://colab.research.google.com/github/cjcastagno/DS1002/blob/main/Conall_Castagno_Pandas_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas exercises 1
#
# 1. Import dependencies

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ---

# %%
list = [98, 24, 46, 87, 33]

# %% [markdown]
# 2. Convert `list` to a pandas series using `pd.Series`

# %%
pandaslist = pd.Series(list)

# %% [markdown]
# 3. Take the above series and add an index that starts at 2 and steps by 3

# %%
pandaslist.index = ['2', '5', '8', '11', '14']
pandaslist
# Out:
# 2     98
# 5     24
# 8     46
# 11    87
# 14    33
# dtype: int64

# %% [markdown]
# 4. Create a dictionary of 4 names, ages, and careers
# Convert this dictionary to a pandas dataframe: `df`.
# Print the dataframe.

# %%
dictionary = {}
dictionary['Name'] = ['John', 'Carl', 'Jim']
dictionary['Age'] = ['23', '24', '25']
dictionary['Career'] = ['Accountat', 'Lawyer', 'Cashier']
df = pd.DataFrame(dictionary)

# %% [markdown]
# 5. Name the index of `df` 'participant_id'.
# Print `df`.

# %%
df.index.name = 'participant_id'
df
# Out:
#                 Name Age     Career
# participant_id
# 0               John  23  Accountat
# 1               Carl  24     Lawyer
# 2                Jim  25    Cashier

# %% [markdown]
# 6. Use a pandas function to determine the data types of the columns of `df`.

# %%
df.dtypes
# Out:
# Name      object
# Age       object
# Career    object
# dtype: object

# %% [markdown]
# 7. Using bracket notation, reference column `name`

# %%
df['Name']
# Out:
# participant_id
# 0    John
# 1    Carl
# 2     Jim
# Name: Name, dtype: object

# %% [markdown]
# 8. Using dot notation, reference column `name`

# %%
df.Name
# Out:
# participant_id
# 0    John
# 1    Carl
# 2     Jim
# Name: Name, dtype: object

# %% [markdown]
# 8. Reference column `name` and have it returned in a dataframe.

# %%
df.Name.values
# Out:
# array(['John', 'Carl', 'Jim'], dtype=object)

# %% [markdown]
# 9. Show the 3rd element in column `career`.

# %%
df.Career.values[2]
# Out:
# 'Cashier'

# %% [markdown]
# 10.  Load the `iris` dataset that we used in class.  Use `iris` as the name of your data frame.

# %%
import seaborn as sns
iris = sns.load_dataset('iris')

# %% [markdown]
# 11.  What is the correlation between the variables `sepal_length` and `sepal_width` for all the irises?

# %%
iris[['sepal_length', 'petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.871754
# petal_length      0.871754      1.000000

# %% [markdown]
# 12.  Which of the three species has the highest correlation between `sepal_length` and `sepal_width`?  Show any calculations you use to support your answer.

# %%
# iris.species.values to get the three species
# iris.iloc[45:51] # 0:50 is setosa
# iris.iloc[95:101] # 51:100 is versicolor, # 101:151 is virginica
setosa_corr = iris[0:50]
versicolor_corr = iris[51:100]
virginica_corr = iris[101:151]
setosa_corr[['sepal_length', 'petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.267176
# petal_length      0.267176      1.000000

# %%
versicolor_corr[['sepal_length', 'petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.754622
# petal_length      0.754622      1.000000

# %%
virginica_corr[['sepal_length', 'petal_length']].corr()
# virginica has the highest correlation
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.879807
# petal_length      0.879807      1.000000

# %% [markdown]
# 13.  Among the four variables, the two that are most negatively correlated (overall) are `sepal_width` and `petal_length`.  (How do we know this?)  Determine the same thing but for each species separately:  for each species, which two variables have the most negative (or the least positive) correlation?  Again, include calculations to support your answer.

# %%
# setosa_corr[['sepal_length', 'petal_length']].corr() .267
#setosa_corr[['sepal_length', 'petal_width']].corr()   .278
# setosa_corr[['sepal_length', 'sepal_width']].corr()    .743
#setosa_corr[['sepal_width', 'petal_width']].corr()       .232
# setosa_corr[['petal_length', 'petal_width']].corr()      .331
 # Setosa's most negative variable correlation is sepal width and petal width

#versicolor_corr[['sepal_length', 'petal_length']].corr()   .755
#versicolor_corr[['sepal_length', 'petal_width']].corr()  .556
# versicolor_corr[['sepal_length', 'sepal_width']].corr()  .499
# versicolor_corr[['sepal_width', 'petal_width']].corr()      .677
# versicolor_corr[['petal_length', 'petal_width']].corr()          .787
#Versicolor's most negative variable correlation is sepal length and sepal width

# virginica_corr[['sepal_length', 'petal_length']].corr()   .879
# virginica_corr[['sepal_length', 'petal_width']].corr()        .307
# virginica_corr[['sepal_length', 'sepal_width']].corr()     .472
# virginica_corr[['sepal_width', 'petal_width']].corr()            .523
# virginica_corr[['petal_length', 'petal_width']].corr()          .304
# Virginica's most negative variable correlation is petal length and petal width
# Out:
#               petal_length  petal_width
# petal_length      1.000000     0.304561
# petal_width       0.304561     1.000000

# %% [markdown]
# 14.  Once again, the variables `sepal_width` and `petal_length` are negatively correlated.  But for each individual species, these two variables are positively correlated.  How is this possible?  Explain this phenomenon.  Use a data visualization if it helps.

# %%
# This is because there is a negative correlation across species. Within an individual species, the variables are positively correlated.
#  But this is not the case when you compare sepal width and petal length across interspecies bounds.
